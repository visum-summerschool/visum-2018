# %% [markdown]
# # Titanic dataset
#
# * Acknowledgment: This notebook is being used with the kind permission of Kelwin Fernandes and Ricardo Cruz
# <img src="titanic.jpg" />
#
# We can start by opening the following files in excel or a similar spreadsheet program:
# * <a href="titanic/train.csv">train.csv</a>
# * <a href="titanic/test.csv">test.csv</a>
#
# -------------------------
#
# We are going to use the `pandas` package to open the files, and then we move on to `numpy`.

# %%
import pandas as pd
train = pd.read_csv('titanic/train.csv')
test = pd.read_csv('titanic/test.csv')
data = pd.concat([train, test], sort=True)

# %%
data
# Out:
#       Age        Cabin Embarked      Fare  \
# 0    22.0          NaN        S    7.2500
# 1    38.0          C85        C   71.2833
# 2    26.0          NaN        S    7.9250
# 3    35.0         C123        S   53.1000
# 4    35.0          NaN        S    8.0500
# 5     NaN          NaN        Q    8.4583
# 6    54.0          E46        S   51.8625
# 7     2.0          NaN        S   21.0750
# 8    27.0          NaN        S   11.1333
# 9    14.0          NaN        C   30.0708
# 10    4.0           G6        S   16.7000
# 11   58.0         C103        S   26.5500
# 12   20.0          NaN        S    8.0500
# 13   39.0          NaN        S   31.2750
# 14   14.0          NaN        S    7.8542
# 15   55.0          NaN        S   16.0000
# 16    2.0          NaN        Q   29.1250
# 17    NaN          NaN        S   13.0000
# 18   31.0          NaN        S   18.0000
# 19    NaN          NaN        C    7.2250
# 20   35.0          NaN        S   26.0000
# ...

# %% [markdown]
# First, let us think...
#
# ### What information from this table can we use?
#
# Can we for instance use name to predict whether someone survived? Do you learn anything from that? What about ticket number?

# %% [markdown]
# Pandas is nicer to explore data than numpy because it supports various types and you can access columns by name.

# %%
data['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
# 5        male
# 6        male
# 7        male
# 8      female
# 9      female
# 10     female
# 11     female
# 12       male
# 13       male
# 14     female
# 15     female
# 16       male
# 17       male
# 18     female
# 19     female
# 20       male
# 21       male
# 22     female
# 23       male
# 24     female
# 25     female
# 26       male
# 27       male
# 28     female
# 29       male
#         ...
# 388      male
# 389      male
# 390      male
# 391    female
# 392      male
# 393      male
# 394      male
# 395    female
# 396      male
# 397    female
# 398      male
# 399      male
# 400    female
# 401      male
# 402    female
# 403      male
# 404      male
# 405      male
# 406      male
# 407      male
# 408    female
# 409    female
# 410    female
# 411    female
# 412    female
# 413      male
# 414    female
# 415      male
# 416      male
# 417      male
# ...

# %%
data['Sex'].value_counts()
# Out:
# male      843
# female    466
# Name: Sex, dtype: int64

# %% [markdown]
# **Exercise 1:** Count the number of men and women who survided and who died.
#
# Also: use plt.bar() to draw a bar plot.

# %%
# %matplotlib inline  
import matplotlib.pyplot as plt

# %% [markdown]
# **Exercise 2:** Use `Age` to predict whether the person `Survived`.  Choose [a classification model](http://scikit-learn.org/stable/supervised_learning.html#supervised-learning) of your choice.

# %% [markdown]
# **Exercise 3:** Use `Sex` to predict whether the person `Survived`.

# %% [markdown]
# **Exercise 4:** Grid search using kfold **one** numeric hyperparameter of the model. Plot the average accuracy in the train and test sets for each value of that hyperparameter. Plot the standard deviation as error bars.
