# %% [markdown]
# # OpenCV - Exercise 1
#
# Simple operations with OpenCV

# %%
import numpy as np
import cv2
# %matplotlib inline
import matplotlib.pyplot as plt

print("OpenCV-Python Version %s" % cv2.__version__)
# Out:
# OpenCV-Python Version 3.4.1

# %% [markdown]
# ## Open/display an image

# %%
img = cv2.imread('feup.jpg', cv2.IMREAD_COLOR)

if img is None:
    print('ERROR: unable to load image')

# %%
# Check the resulting img
print (img.shape)
print (img[:2, :2, :])  # Right-upper-most few pixels of the image
# Out:
# (524, 860, 3)
# [[[233 233 227]
#   [234 234 228]]
#
#  [[232 232 226]
#   [233 233 227]]]

# %%
# display an image using matplotlib
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## Basic operations on Images
# ### 1. Draw an object
#
# - `cv2.line(image, startPoint, endPoint, rgb, thinkness)`
# - `cv2.rectangle(image, topLeft, bottomRight, rgb, thinkness)`
# - `cv2.circle(image, center, radius, rgb, thinkness)`
# - `cv2.ellipse(image, center, axes, angle, startAngle, endAngle, rgb, thinkness)`
# - `cv2.putText(image, text, bottomLeft, fontType, fontScale, rgb, thinkness, lineType)`

# %%
# Create a black image
img2 = np.zeros((512,512,3), np.uint8)
plt.imshow(img2)

# %%
cv2.line(img2, (0,0), (511,511), (255,0,0), 5)
# => Diagonal red line with thickness of 5 px

cv2.rectangle(img2, (384,0), (510,128), (0,255,0), 3)
# => Green rectangle with thickness of 3 px

cv2.circle(img2, (447,63), 63, (0,0,255), -1)
# => Blue filled circle(note that the thinkness is -1)

cv2.ellipse(img2, (256,256), (100,50), -45, 0, 180, (255,0,0), -1)
# => Red wide down-half ellipse

plt.imshow(img2)

# %%
font = cv2.FONT_HERSHEY_COMPLEX
cv2.putText(img2, 'OpenCV', (10,500), font, 4, (255,255,255), 10, cv2.LINE_AA)
# => White 'OpenCV' text at the bottom

plt.imshow(img2)

# %% [markdown]
# ---
#
# ### 2. Modify pixels & ROI
#
# - Accessing/modifying a single pixel or ROI using Numpy indexing.
# - Just like matrix indexing, `img[a, b]` refers to `a`-th row and `b`-th column.

# %%
# Access a pixel value(BGR order)
img[50, 235]
# Out:
# array([127, 115, 109], dtype=uint8)

# %%
# Change pixel values
for i in range(5):
    for j in range(5):
        img[50+i, 235+j] = (0, 255, 0)
# => Green dot just above one of the windows
# img[50:55, 235:240] = (0, 255, 0)  # The for-loop could be replaced by this line

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
# ROI is obtained using Numpy indexing 
ball = img[280:340, 330:390]
img[273:333, 100:160] = ball

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ### Additional exercises
#
# 1. Convert the image from RGB to YUV | [Changing Colorspaces](https://docs.opencv.org/3.4.1/df/d9d/tutorial_py_colorspaces.html)
#
# - Apply Gaussian and median blur; test different parameters | [Smoothing images](https://docs.opencv.org/3.4.1/d4/d13/tutorial_py_filtering.html)
#
# - Binarize the image applying a simple threshold and Otsu's thresholding method | [Image thresholding](https://docs.opencv.org/3.4.1/d7/d4d/tutorial_py_thresholding.html)
#
# ### Acknowledgments
#
# Adapted from OpenCV tutorial by Juyong Kim.
#
# More detailed explanation in the following tutorials:
#
#  - [Basic Operations on Images](https://docs.opencv.org/3.4.1/d3/df2/tutorial_py_basic_ops.html)
#  - [Drawing Functions in OpenCV](https://docs.opencv.org/3.4.1/d1/de0/tutorial_py_feature_homography.html)
